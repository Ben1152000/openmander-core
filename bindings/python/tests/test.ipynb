# %%
import openmander

# %%
iowa_map = openmander.Map("/Users/benjamin/Desktop/openmander/datasets/IA_2020_pack")

# %%
plan = openmander.Plan(iowa_map, num_districts=4)
plan.randomize()
plan.equalize("T_20_CENS_Total", tolerance=0.002, max_iter=1000)
# Out:
# Target population per part: 797592 ±1595
# Merged part 3 into part 1, and split part 4
# 1 (155063): Equalizing part 4 (pop: 935383) and part 1 (pop: 935403)
# 2 (155063): Equalizing part 2 (pop: 642529) and part 3 (pop: 677054)
# 3 (138662): Equalizing part 3 (pop: 658930) and part 2 (pop: 660653)
# 4 (137819): Equalizing part 4 (pop: 935411) and part 1 (pop: 935375)
# 5 (137839): Equalizing part 2 (pop: 659784) and part 3 (pop: 659799)
# 6 (137839): Equalizing part 3 (pop: 659791) and part 4 (pop: 935355)
# 7 (137839): Equalizing part 4 (pop: 731554) and part 3 (pop: 863592)
# 8 (137839): Equalizing part 2 (pop: 659792) and part 3 (pop: 797159)
# 9 (137839): Equalizing part 1 (pop: 935431) and part 3 (pop: 728474)
# 10 (69115): Equalizing part 2 (pop: 728477) and part 3 (pop: 831956)
# 11 (34357): Equalizing part 2 (pop: 780245) and part 4 (pop: 797987)
# 12 (34357): Equalizing part 2 (pop: 789116) and part 1 (pop: 831949)
# ...

# %%
plan.assignments()
# Out:
# array([3, 3, 3, ..., 2, 2, 1], shape=(175199,), dtype=int32)
